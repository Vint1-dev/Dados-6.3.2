# %% [markdown]
# <a href="https://colab.research.google.com/github/Vint1-dev/Dados-6.3.2/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inserir texto no

# %%
import os
pasta = "/content/drive/MyDrive/A Bíblia Sagrada (NVI-PT)"
texto = """---\n
tags:\n
  - Bíblia\n
  - Interesse/Deus\n
---\n
"""

for raiz, subpastas, arquivos in os.walk(pasta):
    for arquivo in arquivos:
        if arquivo.endswith(".md"):
            caminho = os.path.join(raiz, arquivo)

            with open(caminho, "r", encoding="utf-8") as f:
                conteudo = f.readlines()

            conteudo.insert(0, texto)

            with open(caminho, "w", encoding="utf-8") as f:
                f.writelines(conteudo)

print("Concluído!")
# Out:
# Concluído!

# %%
import os
pasta = "/content/drive/MyDrive/Enigma do medo"
texto = """---\n
tags:\n
  - arte/game/enigma_do_medo\n
  - arte/game/puzzle\n
---\n
"""

for raiz, subpastas, arquivos in os.walk(pasta):
    for arquivo in arquivos:
        if arquivo.endswith(".md"):
            caminho = os.path.join(raiz, arquivo)

            with open(caminho, "r", encoding="utf-8") as f:
                conteudo = f.readlines()

            conteudo.insert(0, texto)

            with open(caminho, "w", encoding="utf-8") as f:
                f.writelines(conteudo)

print("Concluído!")
# Out:
# Concluído!

# %%
import os
pasta = "/content/drive/MyDrive/Cursos/MOC Faculdade"
texto = """---\n
tags:\n
  - curso/faculdade\n
---\n
"""

for raiz, subpastas, arquivos in os.walk(pasta):
    for arquivo in arquivos:
        if arquivo.endswith(".md"):
            caminho = os.path.join(raiz, arquivo)

            with open(caminho, "r", encoding="utf-8") as f:
                conteudo = f.readlines()

            conteudo.insert(0, texto)

            with open(caminho, "w", encoding="utf-8") as f:
                f.writelines(conteudo)

print("Concluído!")
# Out:
# Concluído!

# %%
import os
pasta = "/content/drive/MyDrive/Valorant"
texto = """---\n
tags:\n
  - arte/game/valorant\n
---\n
"""

for raiz, subpastas, arquivos in os.walk(pasta):
    for arquivo in arquivos:
        if arquivo.endswith(".md"):
            caminho = os.path.join(raiz, arquivo)

            with open(caminho, "r", encoding="utf-8") as f:
                conteudo = f.readlines()

            conteudo.insert(0, texto)

            with open(caminho, "w", encoding="utf-8") as f:
                f.writelines(conteudo)

print("Concluído!")
# Out:
# Concluído!
